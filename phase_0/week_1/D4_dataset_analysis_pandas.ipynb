# %% [markdown]
# # NBA dataset analysis

# %%
import pandas as pd
import numpy as np

# %%
#cara memanggil file

# df = pd.read_csv("Student_marks.csv") #= apabila ada di folder yang sama dengan ipynbnya
# df = pd.read_csv("dataset/Student_marks.csv") #= apabila ada di folder tapi dengan path yang sama
# df = pd.read_csv("../test/Student_marks.csv") #= .. naik 1 directory
# df = pd.read_csv(r"G:\Abi\learning_journal\phase_0\week_1\dataset\nbaallelo.csv") #= untuk memanggil dengan memakai path
# df = pd.read_csv("dataset/ref.csv", sep=";") #= Apabila ada file yang memakai ; sebagai separatornya, sehingga harus di inisiasi terlebih dahulu (default ,) bisa pake delimiter atau sep. \s+ untuk spasi
df = pd.read_csv('https://raw.githubusercontent.com/ardhiraka/PFDS_sources/master/nbaallelo.csv') #= apabila menggunakan file secara online
# df = pd.read_csv("copy path disini dari upload") #= apabila menggunakan google colab

# %%
len(df)
# Out:
# 126314

# %%
# Melihat jumlah baris n kolom pada dataset
df.shape
# Out:
# (126314, 23)

# %%
#mengambil data 5 (default) teratas
df.head ()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  ...  win_equiv  opp_id  opp_fran  opp_pts  \
# 0            0     TRH  Huskies  ...  40.294830     NYK    Knicks       68
# 1            0     NYK   Knicks  ...  41.705170     TRH   Huskies       66
# 2            0     CHS    Stags  ...  42.012257     NYK    Knicks       47
# 3            0     NYK   Knicks  ...  40.692783     CHS     Stags       63
# 4            0     DTF  Falcons  ...  38.864048     WSC  Capitols       50
#
#    opp_elo_i  opp_elo_n  game_location  game_result  forecast notes
# ...

# %%
pd.set_option("display.max.columns", 28)
df.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts      elo_i      elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.0000  1293.2767  40.294830    NYK
# 1            0     NYK   Knicks   68  1300.0000  1306.7233  41.705170    TRH
# 2            0     CHS    Stags   63  1300.0000  1309.6521  42.012257    NYK
# 3            0     NYK   Knicks   47  1306.7233  1297.0712  40.692783    CHS
# 4            0     DTF  Falcons   33  1300.0000  1279.6189  38.864048    WSC
#
# ...

# %%
pd.set_option("display.precision", 2) #mengubah angka 0 dibelakang koma menjadi 2
df.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts    elo_i    elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.00  1293.28      40.29    NYK
# 1            0     NYK   Knicks   68  1300.00  1306.72      41.71    TRH
# 2            0     CHS    Stags   63  1300.00  1309.65      42.01    NYK
# 3            0     NYK   Knicks   47  1306.72  1297.07      40.69    CHS
# 4            0     DTF  Falcons   33  1300.00  1279.62      38.86    WSC
#
#    opp_fran  opp_pts  opp_elo_i  opp_elo_n game_location game_result  \
# ...

# %%
df.tail()
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts    elo_i    elo_n  \
# 126309         100            1     CLE  Cavaliers   82  1723.41  1704.39
# 126310         102            1     GSW   Warriors  104  1809.98  1813.63
# 126311         101            1     CLE  Cavaliers   91  1704.39  1700.74
# 126312         102            1     CLE  Cavaliers   97  1700.74  1692.09
# 126313         103            1     GSW   Warriors  105  1813.63  1822.29
#
#         win_equiv opp_id   opp_fran  opp_pts  opp_elo_i  opp_elo_n  \
# ...

# %%
df.tail(3)
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts    elo_i    elo_n  \
# 126311         101            1     CLE  Cavaliers   91  1704.39  1700.74
# 126312         102            1     CLE  Cavaliers   97  1700.74  1692.09
# 126313         103            1     GSW   Warriors  105  1813.63  1822.29
#
#         win_equiv opp_id   opp_fran  opp_pts  opp_elo_i  opp_elo_n  \
# 126311      60.01    GSW   Warriors      104    1809.98    1813.63
# 126312      59.29    GSW   Warriors      105    1813.63    1822.29
# 126313      68.52    CLE  Cavaliers       97    1700.74    1692.09
#
#        game_location game_result  forecast notes
# 126311             A           L      0.23   NaN
# ...

# %%
df.sample (5) #ngambil data secara random
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 112996      56499  201003140CLE   NBA        0     2010  3/14/2010
# 25346       12674  197201190DNR   ABA        0     1972  1/19/1972
# 116398      58200  201201010MIA   NBA        0     2012   1/1/2012
# 27680       13841  197301100NYA   ABA        0     1973  1/10/1973
# 11880        5941  196303120NYK   NBA        0     1963  3/12/1963
#
#         seasongame  is_playoffs team_id    fran_id  pts    elo_i    elo_n  \
# 112996          67            0     CLE  Cavaliers  104  1742.93  1745.94
# 25346           46            0     DNR    Nuggets  116  1381.45  1393.25
# 116398           5            0     MIA       Heat  129  1676.80  1681.24
# 27680           45            0     NYA       Nets  105  1348.21  1366.03
# 11880           77            0     NYK     Knicks   96  1331.61  1321.12
#
#         win_equiv opp_id opp_fran  opp_pts  opp_elo_i  opp_elo_n  \
# ...

# %%
# Mengambil info dari dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   gameorder      126314 non-null  int64
#  1   game_id        126314 non-null  object
#  2   lg_id          126314 non-null  object
#  3   _iscopy        126314 non-null  int64
#  4   year_id        126314 non-null  int64
#  5   date_game      126314 non-null  object
#  6   seasongame     126314 non-null  int64
#  7   is_playoffs    126314 non-null  int64
#  8   team_id        126314 non-null  object
#  9   fran_id        126314 non-null  object
#  10  pts            126314 non-null  int64
#  11  elo_i          126314 non-null  float64
#  12  elo_n          126314 non-null  float64
#  13  win_equiv      126314 non-null  float64
#  14  opp_id         126314 non-null  object
#  15  opp_fran       126314 non-null  object
#  16  opp_pts        126314 non-null  int64
# ...

# %%
# Mendescribe mengenai dataset  .T untuk transpose data
df.describe().T
# Out:
#                 count      mean       std      min       25%       50%  \
# gameorder    126314.0  31579.00  18231.93     1.00  15790.00  31579.00
# _iscopy      126314.0      0.50      0.50     0.00      0.00      0.50
# year_id      126314.0   1988.20     17.58  1947.00   1975.00   1990.00
# seasongame   126314.0     43.53     25.38     1.00     22.00     43.00
# is_playoffs  126314.0      0.06      0.24     0.00      0.00      0.00
# pts          126314.0    102.73     14.81     0.00     93.00    103.00
# elo_i        126314.0   1495.24    112.14  1091.64   1417.24   1500.95
# elo_n        126314.0   1495.24    112.46  1085.77   1416.99   1500.95
# win_equiv    126314.0     41.71     10.63    10.15     34.10     42.11
# opp_pts      126314.0    102.73     14.81     0.00     93.00    103.00
# opp_elo_i    126314.0   1495.24    112.14  1091.64   1417.24   1500.95
# opp_elo_n    126314.0   1495.24    112.46  1085.77   1416.99   1500.95
# ...

# %% [markdown]
# ## Data Exploration

# %%
df.head(2)
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
#
#    is_playoffs team_id  fran_id  pts   elo_i    elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.0  1293.28      40.29    NYK
# 1            0     NYK   Knicks   68  1300.0  1306.72      41.71    TRH
#
#   opp_fran  opp_pts  opp_elo_i  opp_elo_n game_location game_result  forecast  \
# 0   Knicks       68     1300.0    1306.72             H           L      0.64
# 1  Huskies       66     1300.0    1293.28             A           W      0.36
#
#   notes
# 0   NaN
# 1   NaN

# %%
# Access multiple columns
df["team_id"].value_counts()
# Out:
# BOS    5997
# NYK    5769
# LAL    5078
# DET    4985
# PHI    4533
#        ...
# INJ      60
# PIT      60
# DTF      60
# TRH      60
# SDS      11
# Name: team_id, Length: 104, dtype: int64

# %%
df["fran_id"].unique()
# Out:
# array(['Huskies', 'Knicks', 'Stags', 'Falcons', 'Capitols', 'Celtics',
#        'Steamrollers', 'Ironmen', 'Bombers', 'Rebels', 'Warriors',
#        'Baltimore', 'Jets', 'Pistons', 'Lakers', 'Kings', 'Hawks',
#        'Denver', 'Olympians', 'Redskins', 'Waterloo', 'Packers', 'Sixers',
#        'Wizards', 'Bulls', 'Thunder', 'Squires', 'Stars', 'Rockets',
#        'Colonels', 'Pacers', 'Nuggets', 'Spurs', 'Spirits', 'Sounds',
#        'Floridians', 'Nets', 'Condors', 'Bucks', 'Suns', 'Clippers',
#        'Cavaliers', 'Trailblazers', 'Sails', 'Jazz', 'Mavericks',
#        'Pelicans', 'Heat', 'Timberwolves', 'Magic', 'Grizzlies',
#        'Raptors', 'Hornets'], dtype=object)

# %%
df["fran_id"].value_counts().head(5)
# Out:
# Lakers      6024
# Celtics     5997
# Knicks      5769
# Warriors    5657
# Pistons     5650
# Name: fran_id, dtype: int64

# %%
df["team_id"].value_counts().head(5)
# Out:
# BOS    5997
# NYK    5769
# LAL    5078
# DET    4985
# PHI    4533
# Name: team_id, dtype: int64

# %% [markdown]
# Terdapat inkonsistensi pada kedua data diatas

# %%
df.loc[df["fran_id"] == "Lakers",:]
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 1136          569  194811040BLB   NBA        1     1949   11/4/1948
# 1152          577  194811060WSC   NBA        1     1949   11/6/1948
# 1159          580  194811090BOS   NBA        1     1949   11/9/1948
# 1170          586  194811110NYK   NBA        1     1949  11/11/1948
# 1183          592  194811130PRO   NBA        1     1949  11/13/1948
# ...           ...           ...   ...      ...      ...         ...
# 126016      63009  201504080DEN   NBA        1     2015    4/8/2015
# 126052      63027  201504100LAL   NBA        0     2015   4/10/2015
# 126086      63044  201504120LAL   NBA        0     2015   4/12/2015
# 126115      63058  201504130SAC   NBA        1     2015   4/13/2015
# 126137      63069  201504150LAL   NBA        0     2015   4/15/2015
#
#         seasongame  is_playoffs team_id fran_id  pts    elo_i    elo_n  \
# 1136             1            0     MNL  Lakers   84  1527.00  1542.25
# ...

# %%
df.loc[df["fran_id"] == "Lakers" , "team_id"]
# Out:
# 1136      MNL
# 1152      MNL
# 1159      MNL
# 1170      MNL
# 1183      MNL
#          ...
# 126016    LAL
# 126052    LAL
# 126086    LAL
# 126115    LAL
# 126137    LAL
# Name: team_id, Length: 6024, dtype: object

# %%
df.loc[df["fran_id"] == "Lakers" , ["team_id" , "fran_id"]]
# Out:
#        team_id fran_id
# 1136       MNL  Lakers
# 1152       MNL  Lakers
# 1159       MNL  Lakers
# 1170       MNL  Lakers
# 1183       MNL  Lakers
# ...        ...     ...
# 126016     LAL  Lakers
# 126052     LAL  Lakers
# 126086     LAL  Lakers
# 126115     LAL  Lakers
# 126137     LAL  Lakers
#
# [6024 rows x 2 columns]

# %%
# Jawaban untuk inkonsistensi diatas
df.loc[df["fran_id"] == "Lakers" , ["team_id" , "fran_id"]].value_counts()
# Out:
# team_id  fran_id
# LAL      Lakers     5078
# MNL      Lakers      946
# dtype: int64

# %%
df.loc[df["fran_id"] == "Falcons" , "pts"].min() 
df.loc[df["fran_id"] == "Falcons" , "pts"].max()
df.loc[df["fran_id"] == "Falcons" , "pts"].mean() #rata-rata
# Out:
# 63.28333333333333

# %% [markdown]
# # Query

# %%
df.head(2)
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
#
#    is_playoffs team_id  fran_id  pts   elo_i    elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.0  1293.28      40.29    NYK
# 1            0     NYK   Knicks   68  1300.0  1306.72      41.71    TRH
#
#   opp_fran  opp_pts  opp_elo_i  opp_elo_n game_location game_result  forecast  \
# 0   Knicks       68     1300.0    1306.72             H           L      0.64
# 1  Huskies       66     1300.0    1293.28             A           W      0.36
#
#   notes
# 0   NaN
# 1   NaN

# %%
df[ df["year_id"] > 2010]
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 113656      56829  201010260BOS   NBA        1     2011  10/26/2010
# 113657      56829  201010260BOS   NBA        0     2011  10/26/2010
# 113658      56830  201010260LAL   NBA        1     2011  10/26/2010
# 113659      56830  201010260LAL   NBA        0     2011  10/26/2010
# 113660      56831  201010260POR   NBA        1     2011  10/26/2010
# ...           ...           ...   ...      ...      ...         ...
# 126309      63155  201506110CLE   NBA        0     2015   6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015   6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015   6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015   6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015   6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts    elo_i    elo_n  \
# 113656           1            0     MIA       Heat   80  1547.36  1543.16
# ...

# %%
df[ df["year_id"] > 2010]["team_id"]
# Out:
# 113656    MIA
# 113657    BOS
# 113658    HOU
# 113659    LAL
# 113660    PHO
#          ...
# 126309    CLE
# 126310    GSW
# 126311    CLE
# 126312    CLE
# 126313    GSW
# Name: team_id, Length: 12658, dtype: object

# %%
#Multiple Conditions

df[(df["year_id"] > 2010) &
    (df["fran_id"] == "Warriors") &
    (df["pts"] > 100) &
    (df["game_result"] == "W")
   ] [["year_id", "fran_id", "pts"]] #untuk menampilkan kolom secara spesifik
# Out:
#         year_id   fran_id  pts
# 113668     2011  Warriors  132
# 113700     2011  Warriors  109
# 113767     2011  Warriors  115
# 113853     2011  Warriors  109
# 113874     2011  Warriors  122
# ...         ...       ...  ...
# 126301     2015  Warriors  104
# 126303     2015  Warriors  108
# 126308     2015  Warriors  103
# 126310     2015  Warriors  104
# 126313     2015  Warriors  105
#
# [193 rows x 3 columns]

# %%
#Quiz
df[
   (df["is_playoffs"] == 1) &
   (df["fran_id"] == "Lakers") &
   (df["game_location"] == "H") &
   (df["year_id"] > 1970)
   ]
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 23811       11906  197103240LAL   NBA        0     1971  3/24/1971
# 23827       11914  197103260LAL   NBA        0     1971  3/26/1971
# 23898       11950  197104010LAL   NBA        0     1971   4/1/1971
# 23934       11968  197104060LAL   NBA        0     1971   4/6/1971
# 23970       11986  197104140LAL   NBA        0     1971  4/14/1971
# ...           ...           ...   ...      ...      ...        ...
# 118345      59173  201205120LAL   NBA        0     2012  5/12/2012
# 118367      59184  201205180LAL   NBA        0     2012  5/18/2012
# 118372      59187  201205190LAL   NBA        0     2012  5/19/2012
# 120926      60464  201304260LAL   NBA        0     2013  4/26/2013
# 120940      60471  201304280LAL   NBA        0     2013  4/28/2013
#
#         seasongame  is_playoffs team_id fran_id  pts    elo_i    elo_n  \
# 23811           83            1     LAL  Lakers  100  1480.75  1484.44
# ...

# %%
#Cara lain dari quiz diatas
df.query("is_playoffs == 1 &\
         fran_id == 'Lakers' &\
         game_location == 'H' &\
         year_id > 1970")
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 23811       11906  197103240LAL   NBA        0     1971  3/24/1971
# 23827       11914  197103260LAL   NBA        0     1971  3/26/1971
# 23898       11950  197104010LAL   NBA        0     1971   4/1/1971
# 23934       11968  197104060LAL   NBA        0     1971   4/6/1971
# 23970       11986  197104140LAL   NBA        0     1971  4/14/1971
# ...           ...           ...   ...      ...      ...        ...
# 118345      59173  201205120LAL   NBA        0     2012  5/12/2012
# 118367      59184  201205180LAL   NBA        0     2012  5/18/2012
# 118372      59187  201205190LAL   NBA        0     2012  5/19/2012
# 120926      60464  201304260LAL   NBA        0     2013  4/26/2013
# 120940      60471  201304280LAL   NBA        0     2013  4/28/2013
#
#         seasongame  is_playoffs team_id fran_id  pts    elo_i    elo_n  \
# 23811           83            1     LAL  Lakers  100  1480.75  1484.44
# ...

# %% [markdown]
# # Grouping & Aggregating

# %%
df.head(3)
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts   elo_i    elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.0  1293.28      40.29    NYK
# 1            0     NYK   Knicks   68  1300.0  1306.72      41.71    TRH
# 2            0     CHS    Stags   63  1300.0  1309.65      42.01    NYK
#
#   opp_fran  opp_pts  opp_elo_i  opp_elo_n game_location game_result  forecast  \
# 0   Knicks       68    1300.00    1306.72             H           L      0.64
# 1  Huskies       66    1300.00    1293.28             A           W      0.36
# 2   Knicks       47    1306.72    1297.07             H           W      0.63
#
#   notes
# 0   NaN
# 1   NaN
# 2   NaN

# %%
df.groupby("fran_id")["pts"].mean()
# Out:
# fran_id
# Baltimore        79.70
# Bombers          71.46
# Bucks           103.70
# Bulls           101.53
# Capitols         76.93
# Cavaliers        99.85
# Celtics         104.47
# Clippers        101.93
# Colonels        111.63
# Condors         115.45
# Denver           77.71
# Falcons          63.28
# Floridians      112.65
# Grizzlies        95.16
# Hawks           101.81
# Heat             96.63
# Hornets          94.51
# Huskies          66.58
# Ironmen          61.23
# Jazz            102.15
# Jets             74.70
# Kings           103.97
# Knicks          100.97
# Lakers          105.82
# Magic            99.43
# Mavericks       102.63
# Nets            101.76
# Nuggets         108.20
# Olympians        81.08
# Pacers          103.69
# Packers          86.01
# Pelicans         97.96
# Pistons         101.37
# Raptors          96.92
# Rebels           71.02
# Redskins         82.65
# Rockets         104.12
# Sails           109.78
# Sixers          103.81
# ...

# %%
df.groupby("game_result")["pts"].value_counts()
# Out:
# game_result  pts
# L            96     1980
#              99     1932
#              98     1920
#              100    1919
#              97     1892
#                     ...
# W            171       1
#              172       1
#              176       1
#              177       1
#              186       1
# Name: pts, Length: 250, dtype: int64

# %%
df["game_location"].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0         H
# 1         A
# 2         H
# 3         A
# 4         H
#          ..
# 126309    H
# 126310    H
# 126311    A
# 126312    H
# 126313    A
# Name: game_location, Length: 126314, dtype: object>

# %%
df.groupby("game_location")["pts"].mean()
# Out:
# game_location
# A    100.86
# H    104.60
# N    104.32
# Name: pts, dtype: float64

# %%
# contoh elaborasi
grup = df.groupby("game_location")

# %%
grup.get_group("A")["pts"].mean()
# Out:
# 100.85661566726853

# %%
grup.get_group("H")["pts"].mean()
# Out:
# 104.60239475434761

# %%
grup.get_group("N")["pts"].mean()
# Out:
# 104.3157894736842

# %%
#contoh multi chain

df[
    (df["year_id"] > 2010) &
    (df["pts"] > 120)
].groupby("fran_id")[["pts"]].mean().sort_values("pts", ascending=False)
# Out:
#                  pts
# fran_id
# Pacers        129.67
# Jazz          128.30
# Trailblazers  128.27
# Bulls         128.11
# Wizards       127.75
# Pelicans      127.75
# Nuggets       127.37
# Nets          127.33
# Thunder       126.74
# Lakers        126.55
# Raptors       126.50
# Mavericks     126.33
# Rockets       126.32
# Clippers      126.24
# Timberwolves  126.10
# Pistons       126.00
# Warriors      126.00
# Hawks         126.00
# Suns          125.75
# Kings         125.68
# Bucks         125.50
# Cavaliers     125.27
# Spurs         125.18
# Heat          125.00
# Magic         125.00
# Grizzlies     124.33
# Knicks        124.32
# Celtics       124.00
# Sixers        123.71
# Hornets       122.60

# %%
#contoh chain

df[
    (df["year_id"] > 2010) &
    (df["pts"] > 120)
].groupby("fran_id")[["pts"]].mean().sort_values("pts", ascending=False)
# Out:
#                  pts
# fran_id
# Pacers        129.67
# Jazz          128.30
# Trailblazers  128.27
# Bulls         128.11
# Wizards       127.75
# Pelicans      127.75
# Nuggets       127.37
# Nets          127.33
# Thunder       126.74
# Lakers        126.55
# Raptors       126.50
# Mavericks     126.33
# Rockets       126.32
# Clippers      126.24
# Timberwolves  126.10
# Pistons       126.00
# Warriors      126.00
# Hawks         126.00
# Suns          125.75
# Kings         125.68
# Bucks         125.50
# Cavaliers     125.27
# Spurs         125.18
# Heat          125.00
# Magic         125.00
# Grizzlies     124.33
# Knicks        124.32
# Celtics       124.00
# Sixers        123.71
# Hornets       122.60

# %% [markdown]
# # Columns Manipulations

# %%
#membuat salinan
df_new = df.copy()
df_new.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts    elo_i    elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.00  1293.28      40.29    NYK
# 1            0     NYK   Knicks   68  1300.00  1306.72      41.71    TRH
# 2            0     CHS    Stags   63  1300.00  1309.65      42.01    NYK
# 3            0     NYK   Knicks   47  1306.72  1297.07      40.69    CHS
# 4            0     DTF  Falcons   33  1300.00  1279.62      38.86    WSC
#
#    opp_fran  opp_pts  opp_elo_i  opp_elo_n game_location game_result  \
# ...

# %%
# Create New Column

df_new["selisih"] = np.abs(df_new["pts"] - df_new["opp_pts"])
df_new.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts    elo_i    elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.00  1293.28      40.29    NYK
# 1            0     NYK   Knicks   68  1300.00  1306.72      41.71    TRH
# 2            0     CHS    Stags   63  1300.00  1309.65      42.01    NYK
# 3            0     NYK   Knicks   47  1306.72  1297.07      40.69    CHS
# 4            0     DTF  Falcons   33  1300.00  1279.62      38.86    WSC
#
#    opp_fran  opp_pts  opp_elo_i  opp_elo_n game_location game_result  \
# ...

# %%
# Rename Column

df_new = df_new.rename(columns={
    "game_location": "loc",
    "game_result": "result"
})
df_new.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts    elo_i    elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.00  1293.28      40.29    NYK
# 1            0     NYK   Knicks   68  1300.00  1306.72      41.71    TRH
# 2            0     CHS    Stags   63  1300.00  1309.65      42.01    NYK
# 3            0     NYK   Knicks   47  1306.72  1297.07      40.69    CHS
# 4            0     DTF  Falcons   33  1300.00  1279.62      38.86    WSC
#
#    opp_fran  opp_pts  opp_elo_i  opp_elo_n loc result  forecast notes  selisih
# ...

# %%
# Drop Column

df_new.drop(["elo_i", "elo_n"], axis=1, inplace=True)

df_new.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts  win_equiv opp_id  opp_fran  opp_pts  \
# 0            0     TRH  Huskies   66      40.29    NYK    Knicks       68
# 1            0     NYK   Knicks   68      41.71    TRH   Huskies       66
# 2            0     CHS    Stags   63      42.01    NYK    Knicks       47
# 3            0     NYK   Knicks   47      40.69    CHS     Stags       63
# 4            0     DTF  Falcons   33      38.86    WSC  Capitols       50
#
#    opp_elo_i  opp_elo_n loc result  forecast notes  selisih
# ...

# %% [markdown]
# drop rows
# - drop year = 1947 & team spesifik - query
# - index kita salin jadikan list
# - list sebagai input .drop, axis = 0

# %%
# creating new column based on existing information using loop

# siapkan list kosong
# buat program loop -> selisih pts dengan opp_pts per baris
# simpan hasil per baris ke list kosong
# convert list yang sudah terisi menjadi kolom

hasil = []
# df.iloc[:,10] - kolom pts
# df.iloc[:,16] - kolom opp-pts

for i in range(len(df_new)):
    selisih = df_new.iloc[i, 10] - df_new.iloc[i, 14]
    hasil.append(selisih)

df_new['menggunakan_loop'] = hasil

# %%
df_new.sample(10)
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 83804       41903  199902160IND   NBA        0     1999   2/16/1999
# 17325        8663  196811050SDR   NBA        0     1969   11/5/1968
# 30321       15161  197402010CHI   NBA        0     1974    2/1/1974
# 30809       15405  197403060INA   ABA        0     1974    3/6/1974
# 125706      62854  201503180MIA   NBA        0     2015   3/18/2015
# 46628       23315  198202020WSB   NBA        1     1982    2/2/1982
# 87758       43880  200010310HOU   NBA        1     2001  10/31/2000
# 104840      52421  200702260PHI   NBA        0     2007   2/26/2007
# 102646      51324  200603310ATL   NBA        0     2006   3/31/2006
# 121208      60605  201311080NOP   NBA        0     2014   11/8/2013
#
#         seasongame  is_playoffs team_id       fran_id  pts  win_equiv opp_id  \
# 83804            7            0     IND        Pacers   78      53.16    MIA
# ...

# %%
# Membuat Plot / diagram pada sebuah dataset
df_new.plot()
# Out:
# C:\Users\Sanz\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\plotting\_matplotlib\core.py:677: UserWarning: The handle <matplotlib.lines.Line2D object at 0x000001B8BA85A7D0> has a label of '_iscopy' which cannot be automatically added to the legend.
#   ax.legend(handles, labels, loc="best", title=title)
# <AxesSubplot:>

# %%
df_new.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts  win_equiv opp_id  opp_fran  opp_pts  \
# 0            0     TRH  Huskies   66      40.29    NYK    Knicks       68
# 1            0     NYK   Knicks   68      41.71    TRH   Huskies       66
# 2            0     CHS    Stags   63      42.01    NYK    Knicks       47
# 3            0     NYK   Knicks   47      40.69    CHS     Stags       63
# 4            0     DTF  Falcons   33      38.86    WSC  Capitols       50
#
# ...
